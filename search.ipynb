# %%
import numpy as np
import time
import pandas as pd
import ipywidgets as widgets
from IPython.display import display
#pip install ipywidgets

#jupyter nbextension enable --py widgetsnbextension

# %%
#Importing from csv
start = time.process_time()
df = pd.read_csv('Data/u20.csv', dtype='str')
df = df.drop(df.columns[0], axis = 1)
print('csv time taken:',time.process_time() - start)
# Out:
# csv time taken: 8.5

# %%
df
# Out:
#                          NAME    TYPE                 DESCRP PERIOD PHASE  \
# 0                  20CP01_STA  COMPND                    NaN    1.0   0.0
# 1          20CP01_STA:STATION     STA         IA BLOCK TYPES    NaN   NaN
# 2                  20CP01_ECB  COMPND                    NaN    1.0   0.0
# 3      20CP01_ECB:PRIMARY_ECB    ECBP         IA BLOCK TYPES    NaN   NaN
# 4           20CP01_ECB:200138    ECB5        ECB BLOCK TYPES    1.0   0.0
# ...                       ...     ...                    ...    ...   ...
# 41454       ROR_AIR:AIR_RATE1    LLAG         GAH B AIR RATE    2.0   0.0
# 41455     ROR_AIR:REALM_CGPL1   REALM        GAH A ROC ALRAM    1.0   0.0
# 41456     ROR_AIR:REALM_CGPL2   REALM        GAH B ROC ALRAM    1.0   0.0
# 41457             20MAN_CNT29  COMPND            IA COMPOUND    1.0   0.0
# 41458          20MAN_CNT29:B1   CALCA  CONTROLLERS IN MANUAL    1.0   0.0
#
#         ON INITON CINHIB GR1DV1 GR1DV2  ... IN31 IN32 PFSOPT PFSOUT  IIN  BIN  \
# ...

# %%
def search(blockname):
    
    print('searching ...')

    start = time.process_time()

    block = blockname
    
    #THE CODE BELOW RETURNS 1 FOR ALL THE CONTAINS
    
    start = time.process_time()
    
    mask = np.column_stack([df[col].str.contains(block, na=False) for col in df])
    final_pd = df.loc[mask.any(axis=1)]
    x = len(final_pd.index)
    
    
    print('Time taken to mask',time.process_time() - start)
    ##

    start = time.process_time()
    
    
    print(block, 'is used in the following blocks \n')
    for i in range(len(final_pd.index)):

        print("Block:", final_pd.iloc[i][0])
        
        #block_btn = widgets.Button(description=final_pd.iloc[i][1])
        #display(block_btn)

        print("Block Type:", final_pd.iloc[i]['TYPE'])
        print("Description", final_pd.iloc[i]['DESCRP'])

        name = np.where(mask)[1][i]

        print("Input is",final_pd.columns[name] )


        print('')
        
    print('Time taken for looping results ',time.process_time() - start)

# %%
textBox = widgets.Text(description='Block Name' )
display(textBox)

btn = widgets.Button(description='Search')
display(btn)



def btn_eventhandler(obj):
    output_all.clear_output()
    with output_all:
        print('Block name is ', textBox.value)
        search(textBox.value)

    
btn.on_click(btn_eventhandler)


output_all = widgets.Output()

#20LAB10_3TX6:B304.PNT
#Wait for 30 seconds
display(output_all)
# Out:
# Text(value='', description='Block Name')
# Button(description='Search', style=ButtonStyle())
# Output()

# %%
textBox = widgets.Text(description='Block Name', value=textBox.description )
display(textBox)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-907f44bddcf8> in <module>
# ----> 1 textBox = widgets.Text(description='Block Name', value=textBox.description )
#       2 display(textBox)
#
# NameError: name 'textBox' is not defined

# %%
search('20LAB10_3TX6:B304.PNT')
# Out:
# searching ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-a75e24202648> in <module>
# ----> 1 search('20LAB10_3TX6:B304.PNT')
#
# <ipython-input-4-eda325697cfc> in search(blockname)
#      11     start = time.process_time()
#      12
# ---> 13     mask = np.column_stack([df[col].str.contains(block, na=False) for col in df])
#      14     final_pd = df.loc[mask.any(axis=1)]
#      15     x = len(final_pd.index)
#
# <ipython-input-4-eda325697cfc> in <listcomp>(.0)
#      11     start = time.process_time()
#      12
# ---> 13     mask = np.column_stack([df[col].str.contains(block, na=False) for col in df])
#      14     final_pd = df.loc[mask.any(axis=1)]
#      15     x = len(final_pd.index)
#
# ~\Anaconda3\lib\site-packages\pandas\core\strings\accessor.py in wrapper(self, *args, **kwargs)
#      99                 )
# ...
